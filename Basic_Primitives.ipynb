# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
import numpy as np
from platform import python_version

# %%
print(python_version())
# Out:
# 3.10.4

# %%
print("Hello World")
# Out:
# Hello World

# %%
def plot_implicit(fn, bbox=(-2.5,2.5)):
    ''' create a plot of an implicit function
    fn  ...implicit function (plot where fn==0)
    bbox ..the x,y,and z limits of plotted interval'''
    xmin, xmax, ymin, ymax, zmin, zmax = bbox*3
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    A = np.linspace(xmin, xmax, 100) # resolution of the contour
    B = np.linspace(xmin, xmax, 15) # number of slices
    A1,A2 = np.meshgrid(A,A) # grid on which the contour is plotted

    for z in B: # plot contours in the XY plane
        X,Y = A1,A2
        Z = fn(X,Y,z)
        cset = ax.contour(X, Y, Z+z, [z], zdir='z')
        # [z] defines the only level to plot for this contour for this value of z

    for y in B: # plot contours in the XZ plane
        X,Z = A1,A2
        Y = fn(X,y,Z)
        cset = ax.contour(X, Y+y, Z, [y], zdir='y')

    for x in B: # plot contours in the YZ plane
        Y,Z = A1,A2
        X = fn(x,Y,Z)
        cset = ax.contour(X+x, Y, Z, [x], zdir='x')

    # must set plot limits because the contour will likely extend
    # way beyond the displayed level.  Otherwise matplotlib extends the plot limits
    # to encompass all values in the contour.
    ax.set_zlim3d(zmin,zmax)
    ax.set_xlim3d(xmin,xmax)
    ax.set_ylim3d(ymin,ymax)

    plt.show()

# %%
def goursat_tangle(x,y,z):
    a,b,c = 0.0,-5.0,11.8
    return x**4+y**4+z**4+a*(x**2+y**2+z**2)**2+b*(x**2+y**2+z**2)+c

plot_implicit(goursat_tangle, (-5.0,5.0))
# Out:
# C:\Users\thara\AppData\Local\Temp\ipykernel_24188\2680735833.py:15: UserWarning: No contour levels were found within the data range.
#   cset = ax.contour(X, Y, Z+z, [z], zdir='z')
# C:\Users\thara\AppData\Local\Temp\ipykernel_24188\2680735833.py:21: UserWarning: No contour levels were found within the data range.
#   cset = ax.contour(X, Y+y, Z, [y], zdir='y')
# C:\Users\thara\AppData\Local\Temp\ipykernel_24188\2680735833.py:26: UserWarning: No contour levels were found within the data range.
#   cset = ax.contour(X+x, Y, Z, [x], zdir='x')

# %%
def spherical_plot(x,y,z):
    a,b,c, r = 0.0,0.0,0.0,20.0
    return (x-a)**2 + (y-b)**2 + (z-c)**2 - (r**2)

plot_implicit(spherical_plot,  (-20.0,20.0))
# Out:
# C:\Users\thara\AppData\Local\Temp\ipykernel_24188\2680735833.py:15: UserWarning: No contour levels were found within the data range.
#   cset = ax.contour(X, Y, Z+z, [z], zdir='z')
# C:\Users\thara\AppData\Local\Temp\ipykernel_24188\2680735833.py:21: UserWarning: No contour levels were found within the data range.
#   cset = ax.contour(X, Y+y, Z, [y], zdir='y')
# C:\Users\thara\AppData\Local\Temp\ipykernel_24188\2680735833.py:26: UserWarning: No contour levels were found within the data range.
#   cset = ax.contour(X+x, Y, Z, [x], zdir='x')

# %%
def planar_plot(x,y,z):
    a,b,c, d = 1.0,0.0,1.0,20.0
    return (a*x)+(b*y)+(c*z)+d

plot_implicit(planar_plot,  (-40.0,40.0))
# Out:
# C:\Users\thara\AppData\Local\Temp\ipykernel_24188\2680735833.py:15: UserWarning: No contour levels were found within the data range.
#   cset = ax.contour(X, Y, Z+z, [z], zdir='z')
# C:\Users\thara\AppData\Local\Temp\ipykernel_24188\2680735833.py:26: UserWarning: No contour levels were found within the data range.
#   cset = ax.contour(X+x, Y, Z, [x], zdir='x')

# %%
def torus_plot(x,y,z):
    k1, k2 = 20.0,10.0
    return ((((((x**2)+(y**2))**(1/2)-k1)**2) + (z**2))**(1/2)) - k2

plot_implicit(torus_plot, (-30.0,30.0))
# Out:
# C:\Users\thara\AppData\Local\Temp\ipykernel_24188\2680735833.py:15: UserWarning: No contour levels were found within the data range.
#   cset = ax.contour(X, Y, Z+z, [z], zdir='z')
# C:\Users\thara\AppData\Local\Temp\ipykernel_24188\2680735833.py:21: UserWarning: No contour levels were found within the data range.
#   cset = ax.contour(X, Y+y, Z, [y], zdir='y')
# C:\Users\thara\AppData\Local\Temp\ipykernel_24188\2680735833.py:26: UserWarning: No contour levels were found within the data range.
#   cset = ax.contour(X+x, Y, Z, [x], zdir='x')

# %%
def rectangular_box(x,y,z):
    center_points = (0.0,0.0,0.0)
    width, height, length =5.0, 5.0, 5.0  
    normalizedXPoint = normalized_point(x, center_points[0], width)
    normalizedYPoint = normalized_point(y, center_points[1], length)
    normalizedZPoint = normalized_point(z, center_points[2], height)
    #return ((1/2)-max(max(normalizedXPoint, normalizedYPoint), normalizedZPoint))
    max_values = np.fmax(normalizedXPoint, np.fmax(normalizedYPoint, normalizedZPoint))
    max_values_shape = max_values.shape
    normalizedZPoint_shape = normalizedZPoint.shape
    if isinstance(normalizedZPoint, float) and abs(normalizedZPoint) == 0.0:
        return np.fmax(normalizedXPoint, normalizedYPoint)
    elif isinstance(normalizedYPoint, float) and abs(normalizedYPoint) == 0.0:
        return np.fmax(normalizedXPoint, normalizedZPoint)
    elif isinstance(normalizedXPoint, float) and abs(normalizedXPoint) == 0.0:
        return np.fmax(normalizedYPoint, normalizedZPoint)
    else:
        return np.zeros(max_values.shape)

def normalized_point(coord_on_axis, coord_of_center, dim_along_axis):
    return (coord_on_axis - coord_of_center)/dim_along_axis
    
plot_implicit(rectangular_box, (-50, 50))
# Out:
# C:\Users\thara\AppData\Local\Temp\ipykernel_24188\2680735833.py:15: UserWarning: No contour levels were found within the data range.
#   cset = ax.contour(X, Y, Z+z, [z], zdir='z')
# C:\Users\thara\AppData\Local\Temp\ipykernel_24188\2680735833.py:15: UserWarning: No contour levels were found within the data range.
#   cset = ax.contour(X, Y, Z+z, [z], zdir='z')
# C:\Users\thara\AppData\Local\Temp\ipykernel_24188\2680735833.py:15: UserWarning: No contour levels were found within the data range.
#   cset = ax.contour(X, Y, Z+z, [z], zdir='z')
# C:\Users\thara\AppData\Local\Temp\ipykernel_24188\2680735833.py:15: UserWarning: No contour levels were found within the data range.
#   cset = ax.contour(X, Y, Z+z, [z], zdir='z')
# C:\Users\thara\AppData\Local\Temp\ipykernel_24188\2680735833.py:15: UserWarning: No contour levels were found within the data range.
#   cset = ax.contour(X, Y, Z+z, [z], zdir='z')
# ...

# %%
def cone(x,y,z):
    a,b,c = 0.01,0.01,0.01
    return (a*(x**2)) + (b*(y**2)) + (c*(z**2))

plot_implicit(cone, (-0.5,0.5))
# Out:
# C:\Users\thara\AppData\Local\Temp\ipykernel_24188\2680735833.py:15: UserWarning: No contour levels were found within the data range.
#   cset = ax.contour(X, Y, Z+z, [z], zdir='z')
# C:\Users\thara\AppData\Local\Temp\ipykernel_24188\2680735833.py:21: UserWarning: No contour levels were found within the data range.
#   cset = ax.contour(X, Y+y, Z, [y], zdir='y')
# C:\Users\thara\AppData\Local\Temp\ipykernel_24188\2680735833.py:26: UserWarning: No contour levels were found within the data range.
#   cset = ax.contour(X+x, Y, Z, [x], zdir='x')
