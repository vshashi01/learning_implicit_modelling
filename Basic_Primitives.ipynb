# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
import numpy as np
from platform import python_version

# %%
print(python_version())
# Out:
# 3.10.4

# %%
print("Hello World")
# Out:
# Hello World

# %%
def plot_implicit(fn, bbox=(-2.5,2.5)):
    ''' create a plot of an implicit function
    fn  ...implicit function (plot where fn==0)
    bbox ..the x,y,and z limits of plotted interval'''
    xmin, xmax, ymin, ymax, zmin, zmax = bbox*3
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    A = np.linspace(xmin, xmax, 100) # resolution of the contour
    B = np.linspace(xmin, xmax, 15) # number of slices
    A1,A2 = np.meshgrid(A,A) # grid on which the contour is plotted

    for z in B: # plot contours in the XY plane
        X,Y = A1,A2
        Z = fn(X,Y,z)
        cset = ax.contour(X, Y, Z+z, [z], zdir='z')
        # [z] defines the only level to plot for this contour for this value of z

    for y in B: # plot contours in the XZ plane
        X,Z = A1,A2
        Y = fn(X,y,Z)
        cset = ax.contour(X, Y+y, Z, [y], zdir='y')

    for x in B: # plot contours in the YZ plane
        Y,Z = A1,A2
        X = fn(x,Y,Z)
        cset = ax.contour(X+x, Y, Z, [x], zdir='x')

    # must set plot limits because the contour will likely extend
    # way beyond the displayed level.  Otherwise matplotlib extends the plot limits
    # to encompass all values in the contour.
    ax.set_zlim3d(zmin,zmax)
    ax.set_xlim3d(xmin,xmax)
    ax.set_ylim3d(ymin,ymax)

    plt.show()

# %%
def goursat_tangle(x,y,z):
    a,b,c = 0.0,-5.0,11.8
    return x**4+y**4+z**4+a*(x**2+y**2+z**2)**2+b*(x**2+y**2+z**2)+c

plot_implicit(goursat_tangle, (-5.0,5.0))
# Out:
# C:\Users\SVelosamy\AppData\Local\Temp\ipykernel_12876\2680735833.py:15: UserWarning: No contour levels were found within the data range.
#   cset = ax.contour(X, Y, Z+z, [z], zdir='z')
# C:\Users\SVelosamy\AppData\Local\Temp\ipykernel_12876\2680735833.py:21: UserWarning: No contour levels were found within the data range.
#   cset = ax.contour(X, Y+y, Z, [y], zdir='y')
# C:\Users\SVelosamy\AppData\Local\Temp\ipykernel_12876\2680735833.py:26: UserWarning: No contour levels were found within the data range.
#   cset = ax.contour(X+x, Y, Z, [x], zdir='x')

# %%
def spherical_plot(x,y,z):
    a,b,c, r = 0.0,0.0,0.0,20.0
    return (x-a)**2 + (y-b)**2 + (z-c)**2 - (r**2)

plot_implicit(spherical_plot,  (-20.0,20.0))
# Out:
# C:\Users\SVelosamy\AppData\Local\Temp\ipykernel_12876\2680735833.py:15: UserWarning: No contour levels were found within the data range.
#   cset = ax.contour(X, Y, Z+z, [z], zdir='z')
# C:\Users\SVelosamy\AppData\Local\Temp\ipykernel_12876\2680735833.py:21: UserWarning: No contour levels were found within the data range.
#   cset = ax.contour(X, Y+y, Z, [y], zdir='y')
# C:\Users\SVelosamy\AppData\Local\Temp\ipykernel_12876\2680735833.py:26: UserWarning: No contour levels were found within the data range.
#   cset = ax.contour(X+x, Y, Z, [x], zdir='x')

# %%
def planar_plot(x,y,z):
    a,b,c, d = 1.0,0.0,1.0,20.0
    return (a*x)+(b*y)+(c*z)+d

plot_implicit(planar_plot,  (-40.0,40.0))
# Out:
# C:\Users\SVelosamy\AppData\Local\Temp\ipykernel_12876\2680735833.py:15: UserWarning: No contour levels were found within the data range.
#   cset = ax.contour(X, Y, Z+z, [z], zdir='z')
# C:\Users\SVelosamy\AppData\Local\Temp\ipykernel_12876\2680735833.py:26: UserWarning: No contour levels were found within the data range.
#   cset = ax.contour(X+x, Y, Z, [x], zdir='x')

# %%
def torus_plot(x,y,z):
    k1, k2 = 20.0,10.0
    return ((((((x**2)+(y**2))**(1/2)-k1)**2) + (z**2))**(1/2)) - k2

plot_implicit(torus_plot, (-30.0,30.0))
# Out:
# C:\Users\SVelosamy\AppData\Local\Temp\ipykernel_12876\2680735833.py:15: UserWarning: No contour levels were found within the data range.
#   cset = ax.contour(X, Y, Z+z, [z], zdir='z')
# C:\Users\SVelosamy\AppData\Local\Temp\ipykernel_12876\2680735833.py:21: UserWarning: No contour levels were found within the data range.
#   cset = ax.contour(X, Y+y, Z, [y], zdir='y')
# C:\Users\SVelosamy\AppData\Local\Temp\ipykernel_12876\2680735833.py:26: UserWarning: No contour levels were found within the data range.
#   cset = ax.contour(X+x, Y, Z, [x], zdir='x')

# %%
def rectangular_box(x,y,z):
    centerX, centerY, centerZ = 0.0,0.0,0.0
    width, height, length = 1.0, 1.0, 1.0   
    normalizedXPoint = calculate_normalized_point(x.all(), centerX, width)
    normalizedYPoint = calculate_normalized_point(y.all(), centerY, length)
    normalizedZPoint = calculate_normalized_point(z.all(), centerZ, height)
    return ((1/2)-max(max(normalizedXPoint, normalizedYPoint), normalizedZPoint))

def calculate_normalized_point(coordinate_on_axis, offset_from_center, extend_along_axis):
    return (abs(coordinate_on_axis - offset_from_center))/extend_along_axis
    
plot_implicit(rectangular_box, (-20,20))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Untitled-1.ipynb Cell 9' in <cell line: 12>()
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000009untitled?line=8'>9</a> def calculate_normalized_point(coordinate_on_axis, offset_from_center, extend_along_axis):
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000009untitled?line=9'>10</a>     return (abs(coordinate_on_axis - offset_from_center))/extend_along_axis
# ---> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000009untitled?line=11'>12</a> plot_implicit(rectangular_box, (-20,20))
#
# Untitled-1.ipynb Cell 4' in plot_implicit(fn, bbox)
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000002untitled?line=12'>13</a>     X,Y = A1,A2
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000002untitled?line=13'>14</a>     Z = fn(X,Y,z)
# ---> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000002untitled?line=14'>15</a>     cset = ax.contour(X, Y, Z+z, [z], zdir='z')
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000002untitled?line=15'>16</a>     # [z] defines the only level to plot for this contour for this value of z
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000002untitled?line=17'>18</a> for y in B: # plot contours in the XZ plane
#
# File c:\Users\SVelosamy\Miniconda3\envs\ImplicitModel\lib\site-packages\matplotlib\__init__.py:1412, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1409 @functools.wraps(func)
#    1410 def inner(ax, *args, data=None, **kwargs):
#    1411     if data is None:
# -> 1412         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1414     bound = new_sig.bind(ax, *args, **kwargs)
#    1415     auto_label = (bound.arguments.get(label_namer)
#    1416                   or bound.kwargs.get(label_namer))
#
# File c:\Users\SVelosamy\Miniconda3\envs\ImplicitModel\lib\site-packages\mpl_toolkits\mplot3d\axes3d.py:2136, in Axes3D.contour(self, X, Y, Z, extend3d, stride, zdir, offset, *args, **kwargs)
#    2133 had_data = self.has_data()
#    2135 jX, jY, jZ = art3d.rotate_axes(X, Y, Z, zdir)
# -> 2136 cset = super().contour(jX, jY, jZ, *args, **kwargs)
#    2137 self.add_contour_set(cset, extend3d, stride, zdir, offset)
#    2139 self.auto_scale_xyz(X, Y, Z, had_data)
#
# File c:\Users\SVelosamy\Miniconda3\envs\ImplicitModel\lib\site-packages\matplotlib\__init__.py:1412, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1409 @functools.wraps(func)
#    1410 def inner(ax, *args, data=None, **kwargs):
#    1411     if data is None:
# -> 1412         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1414     bound = new_sig.bind(ax, *args, **kwargs)
#    1415     auto_label = (bound.arguments.get(label_namer)
#    1416                   or bound.kwargs.get(label_namer))
#
# File c:\Users\SVelosamy\Miniconda3\envs\ImplicitModel\lib\site-packages\matplotlib\axes\_axes.py:6301, in Axes.contour(self, *args, **kwargs)
#    6292 """
#    6293 Plot contour lines.
#    6294
#    (...)
#    6298 %(contour_doc)s
#    6299 """
#    6300 kwargs['filled'] = False
# -> 6301 contours = mcontour.QuadContourSet(self, *args, **kwargs)
#    6302 self._request_autoscale_view()
#    6303 return contours
#
# File c:\Users\SVelosamy\Miniconda3\envs\ImplicitModel\lib\site-packages\matplotlib\contour.py:812, in ContourSet.__init__(self, ax, levels, filled, linewidths, linestyles, hatches, alpha, origin, extent, cmap, colors, norm, vmin, vmax, extend, antialiased, nchunk, locator, transform, *args, **kwargs)
#     808     self.origin = mpl.rcParams['image.origin']
#     810 self._transform = transform
# --> 812 kwargs = self._process_args(*args, **kwargs)
#     813 self._process_levels()
#     815 self._extend_min = self.extend in ['min', 'both']
#
# File c:\Users\SVelosamy\Miniconda3\envs\ImplicitModel\lib\site-packages\matplotlib\contour.py:1441, in QuadContourSet._process_args(self, corner_mask, *args, **kwargs)
#    1438     corner_mask = mpl.rcParams['contour.corner_mask']
#    1439 self._corner_mask = corner_mask
# -> 1441 x, y, z = self._contour_args(args, kwargs)
#    1443 _mask = ma.getmask(z)
#    1444 if _mask is ma.nomask or not _mask.any():
#
# File c:\Users\SVelosamy\Miniconda3\envs\ImplicitModel\lib\site-packages\matplotlib\contour.py:1480, in QuadContourSet._contour_args(self, args, kwargs)
#    1478     args = args[1:]
#    1479 elif Nargs <= 4:
# -> 1480     x, y, z = self._check_xyz(args[:3], kwargs)
#    1481     args = args[3:]
#    1482 else:
#
# File c:\Users\SVelosamy\Miniconda3\envs\ImplicitModel\lib\site-packages\matplotlib\contour.py:1508, in QuadContourSet._check_xyz(self, args, kwargs)
#    1505 z = ma.asarray(args[2], dtype=np.float64)
#    1507 if z.ndim != 2:
# -> 1508     raise TypeError(f"Input z must be 2D, not {z.ndim}D")
#    1509 if z.shape[0] < 2 or z.shape[1] < 2:
#    1510     raise TypeError(f"Input z must be at least a (2, 2) shaped array, "
#    1511                     f"but has shape {z.shape}")
#
# TypeError: Input z must be 2D, not 0D

# %%
def cone(x,y,z):
    a,b,c = 0.01,0.01,0.01
    return (a*(x**2)) + (b*(y**2)) + (c*(z**2))

plot_implicit(cone, (-0.5,0.5))
# Out:
# C:\Users\SVelosamy\AppData\Local\Temp\ipykernel_12876\2680735833.py:15: UserWarning: No contour levels were found within the data range.
#   cset = ax.contour(X, Y, Z+z, [z], zdir='z')
# C:\Users\SVelosamy\AppData\Local\Temp\ipykernel_12876\2680735833.py:21: UserWarning: No contour levels were found within the data range.
#   cset = ax.contour(X, Y+y, Z, [y], zdir='y')
# C:\Users\SVelosamy\AppData\Local\Temp\ipykernel_12876\2680735833.py:26: UserWarning: No contour levels were found within the data range.
#   cset = ax.contour(X+x, Y, Z, [x], zdir='x')
